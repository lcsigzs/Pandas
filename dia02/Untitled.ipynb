# %%
import pandas as pd

# %%
df = pd.read_csv("despesa_ceaps_2022.csv" , sep=";", encoding='iso-8859-1')
df
# Out:
#                                                                                                                                                                                                                   ULTIMA ATUALIZACAO  \
# ANO  MES SENADOR          TIPO_DESPESA                                       CNPJ_CPF           FORNECEDOR                        DOCUMENTO         DATA       DETALHAMENTO                                        VALOR_REEMBOLSADO
# 2022 1   ACIR GURGACZ     Aluguel de imóveis para escritório político, co... 004.948.028-63     GILBERTO PISELO DO NASCIMENTO     001/22            03/01/2022 Despesa com pagamento de aluguel de imóvel para...               6000
#                           Divulgação da atividade parlamentar                26.320.603/0001-64 INFORMANAHORA                     000000000000310/A 04/01/2022 Despesa com divulgação da atividade parlamentar...               1500
# ...

# %%
df.head()
# Out:
#                                                                                                                                                                                                               ULTIMA ATUALIZACAO  \
# ANO  MES SENADOR      TIPO_DESPESA                                       CNPJ_CPF           FORNECEDOR                        DOCUMENTO         DATA       DETALHAMENTO                                        VALOR_REEMBOLSADO
# 2022 1   ACIR GURGACZ Aluguel de imóveis para escritório político, co... 004.948.028-63     GILBERTO PISELO DO NASCIMENTO     001/22            03/01/2022 Despesa com pagamento de aluguel de imóvel para...               6000
#                       Divulgação da atividade parlamentar                26.320.603/0001-64 INFORMANAHORA                     000000000000310/A 04/01/2022 Despesa com divulgação da atividade parlamentar...               1500
# ...

# %%
df.tail()
# Out:
#                                                                                                               ULTIMA ATUALIZACAO  \
# 2008 11 WELLINGTON SALGADO DE OLIVEIRA Locomoção, hospedagem, alimentação, combustívei... NaN NaN NaN NaN NaN            6152,97
#      12 WELLINGTON SALGADO DE OLIVEIRA Aluguel de imóveis para escritório político, co... NaN NaN NaN NaN NaN            3818,87
#                                        Aquisição de material de consumo para uso no es... NaN NaN NaN NaN NaN             886,66
#                                        Contratação de consultorias, assessorias, pesqu... NaN NaN NaN NaN NaN               7070
#                                        Locomoção, hospedagem, alimentação, combustívei... NaN NaN NaN NaN NaN            2967,79
#
#                                                                                                               06/08/2021 02:00
# ...

# %%
df.describe()
# Out:
#        ULTIMA ATUALIZACAO 05/09/2024 02:01
# count               16806            16806
# unique               9536            16806
# top                   200    COD_DOCUMENTO
# freq                  364                1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 16806 entries, ('ANO', 'MES', 'SENADOR', 'TIPO_DESPESA', 'CNPJ_CPF', 'FORNECEDOR', 'DOCUMENTO', 'DATA', 'DETALHAMENTO') to ('2022', '12', 'ZEQUINHA MARINHO', 'Passagens aéreas, aquáticas e terrestres nacionais', '22.052.777/0001-32', 'Exceller Tour', 'WMQWBX', '30/12/2022', 'Companhia Aérea: TAM, Localizador: WMQWBX. Passageiros: YURI PEREIRA CARNEIRO AGE (Matrícula 300461, COMISSIONADO), Voo: 3608 - BSB/BELÉM - 08/01/2023; YURI PEREIRA CARNEIRO AGE (Matrícula 300461, COMISSIONADO), Voo: 3609 - BELÉM/BSB - 20/01/2023;')
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ULTIMA ATUALIZACAO  16806 non-null  object
#  1   05/09/2024 02:01    16806 non-null  object
# dtypes: object(2)
# memory usage: 1.5+ MB
